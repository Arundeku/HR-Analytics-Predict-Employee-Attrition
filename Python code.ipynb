# %%
#Loading all Packages
print("==================== BLOCK 1 Started! ======================")

# Library for Data Manipulation
import numpy as np
import pandas as pd

#Library for Data Visualization.
import seaborn as sns
import matplotlib.pyplot as plt
import hvplot

# %matplotlib inline
sns.set_style("whitegrid")
plt.style.use("fivethirtyeight")

# Library for Statistical Modelling
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, precision_recall_curve, roc_curve
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression


print("==================== Packages Loaded ======================")

# Library for Ignore the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')
# Out:
# ==================== BLOCK 1 Started! ======================
# ==================== Packages Loaded ======================

# %%
employee_data = pd.read_csv(r'IBM-HR-Analytics-Employee-Attrition-and-Performance-Revised.csv')

# %%
# Print top 5 rows in the dataframe.
employee_data.head().style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# #T_40b08_row0_col0, #T_40b08_row0_col1, #T_40b08_row0_col2, #T_40b08_row0_col3, #T_40b08_row0_col4, #T_40b08_row0_col5, #T_40b08_row0_col6, #T_40b08_row0_col7, #T_40b08_row0_col8, #T_40b08_row0_col9, #T_40b08_row0_col10, #T_40b08_row0_col11, #T_40b08_row0_col12, #T_40b08_row0_col13, #T_40b08_row0_col14, #T_40b08_row0_col15, #T_40b08_row0_col16, #T_40b08_row0_col17, #T_40b08_row0_col18, #T_40b08_row0_col19, #T_40b08_row0_col20, #T_40b08_row0_col21, #T_40b08_row0_col22, #T_40b08_row0_col23, #T_40b08_row0_col24, #T_40b08_row0_col25, #T_40b08_row0_col26, #T_40b08_row0_col27, #T_40b08_row0_col28, #T_40b08_row0_col29, #T_40b08_row0_col30, #T_40b08_row1_col0, #T_40b08_row1_col1, #T_40b08_row1_col2, #T_40b08_row1_col3, #T_40b08_row1_col4, #T_40b08_row1_col5, #T_40b08_row1_col6, #T_40b08_row1_col7, #T_40b08_row1_col8, #T_40b08_row1_col9, #T_40b08_row1_col10, #T_40b08_row1_col11, #T_40b08_row1_col12, #T_40b08_row1_col13, #T_40b08_row1_col14, #T_40b08_row1_col15, #T_40b08_row1_col16, #T_40b08_row1_col17, #T_40b08_row1_col18, #T_40b08_row1_col19, #T_40b08_row1_col20, #T_40b08_row1_col21, #T_40b08_row1_col22, #T_40b08_row1_col23, #T_40b08_row1_col24, #T_40b08_row1_col25, #T_40b08_row1_col26, #T_40b08_row1_col27, #T_40b08_row1_col28, #T_40b08_row1_col29, #T_40b08_row1_col30, #T_40b08_row2_col0, #T_40b08_row2_col1, #T_40b08_row2_col2, #T_40b08_row2_col3, #T_40b08_row2_col4, #T_40b08_row2_col5, #T_40b08_row2_col6, #T_40b08_row2_col7, #T_40b08_row2_col8, #T_40b08_row2_col9, #T_40b08_row2_col10, #T_40b08_row2_col11, #T_40b08_row2_col12, #T_40b08_row2_col13, #T_40b08_row2_col14, #T_40b08_row2_col15, #T_40b08_row2_col16, #T_40b08_row2_col17, #T_40b08_row2_col18, #T_40b08_row2_col19, #T_40b08_row2_col20, #T_40b08_row2_col21, #T_40b08_row2_col22, #T_40b08_row2_col23, #T_40b08_row2_col24, #T_40b08_row2_col25, #T_40b08_row2_col26, #T_40b08_row2_col27, #T_40b08_row2_col28, #T_40b08_row2_col29, #T_40b08_row2_col30, #T_40b08_row3_col0, #T_40b08_row3_col1, #T_40b08_row3_col2, #T_40b08_row3_col3, #T_40b08_row3_col4, #T_40b08_row3_col5, #T_40b08_row3_col6, #T_40b08_row3_col7, #T_40b08_row3_col8, #T_40b08_row3_col9, #T_40b08_row3_col10, #T_40b08_row3_col11, #T_40b08_row3_col12, #T_40b08_row3_col13, #T_40b08_row3_col14, #T_40b08_row3_col15, #T_40b08_row3_col16, #T_40b08_row3_col17, #T_40b08_row3_col18, #T_40b08_row3_col19, #T_40b08_row3_col20, #T_40b08_row3_col21, #T_40b08_row3_col22, #T_40b08_row3_col23, #T_40b08_row3_col24, #T_40b08_row3_col25, #T_40b08_row3_col26, #T_40b08_row3_col27, #T_40b08_row3_col28, #T_40b08_row3_col29, #T_40b08_row3_col30, #T_40b08_row4_col0, #T_40b08_row4_col1, #T_40b08_row4_col2, #T_40b08_row4_col3, #T_40b08_row4_col4, #T_40b08_row4_col5, #T_40b08_row4_col6, #T_40b08_row4_col7, #T_40b08_row4_col8, #T_40b08_row4_col9, #T_40b08_row4_col10, #T_40b08_row4_col11, #T_40b08_row4_col12, #T_40b08_row4_col13, #T_40b08_row4_col14, #T_40b08_row4_col15, #T_40b08_row4_col16, #T_40b08_row4_col17, #T_40b08_row4_col18, #T_40b08_row4_col19, #T_40b08_row4_col20, #T_40b08_row4_col21, #T_40b08_row4_col22, #T_40b08_row4_col23, #T_40b08_row4_col24, #T_40b08_row4_col25, #T_40b08_row4_col26, #T_40b08_row4_col27, #T_40b08_row4_col28, #T_40b08_row4_col29, #T_40b08_row4_col30 {
#   background-color: #E9F6E2;
#   color: black;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_40b08">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40b08_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_40b08_level0_col1" class="col_heading level0 col1" >Attrition</th>
#       <th id="T_40b08_level0_col2" class="col_heading level0 col2" >BusinessTravel</th>
#       <th id="T_40b08_level0_col3" class="col_heading level0 col3" >DailyRate</th>
#       <th id="T_40b08_level0_col4" class="col_heading level0 col4" >Department</th>
#       <th id="T_40b08_level0_col5" class="col_heading level0 col5" >DistanceFromHome</th>
#       <th id="T_40b08_level0_col6" class="col_heading level0 col6" >Education</th>
#       <th id="T_40b08_level0_col7" class="col_heading level0 col7" >EducationField</th>
#       <th id="T_40b08_level0_col8" class="col_heading level0 col8" >EnvironmentSatisfaction</th>
#       <th id="T_40b08_level0_col9" class="col_heading level0 col9" >Gender</th>
#       <th id="T_40b08_level0_col10" class="col_heading level0 col10" >HourlyRate</th>
#       <th id="T_40b08_level0_col11" class="col_heading level0 col11" >JobInvolvement</th>
#       <th id="T_40b08_level0_col12" class="col_heading level0 col12" >JobLevel</th>
#       <th id="T_40b08_level0_col13" class="col_heading level0 col13" >JobRole</th>
#       <th id="T_40b08_level0_col14" class="col_heading level0 col14" >JobSatisfaction</th>
#       <th id="T_40b08_level0_col15" class="col_heading level0 col15" >MaritalStatus</th>
#       <th id="T_40b08_level0_col16" class="col_heading level0 col16" >MonthlyIncome</th>
#       <th id="T_40b08_level0_col17" class="col_heading level0 col17" >MonthlyRate</th>
#       <th id="T_40b08_level0_col18" class="col_heading level0 col18" >NumCompaniesWorked</th>
#       <th id="T_40b08_level0_col19" class="col_heading level0 col19" >OverTime</th>
#       <th id="T_40b08_level0_col20" class="col_heading level0 col20" >PercentSalaryHike</th>
#       <th id="T_40b08_level0_col21" class="col_heading level0 col21" >PerformanceRating</th>
#       <th id="T_40b08_level0_col22" class="col_heading level0 col22" >RelationshipSatisfaction</th>
#       <th id="T_40b08_level0_col23" class="col_heading level0 col23" >StockOptionLevel</th>
#       <th id="T_40b08_level0_col24" class="col_heading level0 col24" >TotalWorkingYears</th>
#       <th id="T_40b08_level0_col25" class="col_heading level0 col25" >TrainingTimesLastYear</th>
#       <th id="T_40b08_level0_col26" class="col_heading level0 col26" >WorkLifeBalance</th>
#       <th id="T_40b08_level0_col27" class="col_heading level0 col27" >YearsAtCompany</th>
#       <th id="T_40b08_level0_col28" class="col_heading level0 col28" >YearsInCurrentRole</th>
#       <th id="T_40b08_level0_col29" class="col_heading level0 col29" >YearsSinceLastPromotion</th>
#       <th id="T_40b08_level0_col30" class="col_heading level0 col30" >YearsWithCurrManager</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40b08_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40b08_row0_col0" class="data row0 col0" >41</td>
#       <td id="T_40b08_row0_col1" class="data row0 col1" >Yes</td>
#       <td id="T_40b08_row0_col2" class="data row0 col2" >Travel_Rarely</td>
#       <td id="T_40b08_row0_col3" class="data row0 col3" >1102</td>
#       <td id="T_40b08_row0_col4" class="data row0 col4" >Sales</td>
#       <td id="T_40b08_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_40b08_row0_col6" class="data row0 col6" >College</td>
#       <td id="T_40b08_row0_col7" class="data row0 col7" >Life Sciences</td>
#       <td id="T_40b08_row0_col8" class="data row0 col8" >Medium</td>
#       <td id="T_40b08_row0_col9" class="data row0 col9" >Female</td>
#       <td id="T_40b08_row0_col10" class="data row0 col10" >94</td>
#       <td id="T_40b08_row0_col11" class="data row0 col11" >High</td>
#       <td id="T_40b08_row0_col12" class="data row0 col12" >Junior Level</td>
#       <td id="T_40b08_row0_col13" class="data row0 col13" >Sales Executive</td>
#       <td id="T_40b08_row0_col14" class="data row0 col14" >Very High</td>
#       <td id="T_40b08_row0_col15" class="data row0 col15" >Single</td>
#       <td id="T_40b08_row0_col16" class="data row0 col16" >5993</td>
#       <td id="T_40b08_row0_col17" class="data row0 col17" >19479</td>
#       <td id="T_40b08_row0_col18" class="data row0 col18" >8</td>
#       <td id="T_40b08_row0_col19" class="data row0 col19" >Yes</td>
#       <td id="T_40b08_row0_col20" class="data row0 col20" >11</td>
#       <td id="T_40b08_row0_col21" class="data row0 col21" >Excellent</td>
#       <td id="T_40b08_row0_col22" class="data row0 col22" >Low</td>
#       <td id="T_40b08_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_40b08_row0_col24" class="data

# %%
# Print bottom 5 rows in the dataframe.
employee_data.tail().style.set_properties(**{'background-color': '#E9F6E2','color': 'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# #T_fd084_row0_col0, #T_fd084_row0_col1, #T_fd084_row0_col2, #T_fd084_row0_col3, #T_fd084_row0_col4, #T_fd084_row0_col5, #T_fd084_row0_col6, #T_fd084_row0_col7, #T_fd084_row0_col8, #T_fd084_row0_col9, #T_fd084_row0_col10, #T_fd084_row0_col11, #T_fd084_row0_col12, #T_fd084_row0_col13, #T_fd084_row0_col14, #T_fd084_row0_col15, #T_fd084_row0_col16, #T_fd084_row0_col17, #T_fd084_row0_col18, #T_fd084_row0_col19, #T_fd084_row0_col20, #T_fd084_row0_col21, #T_fd084_row0_col22, #T_fd084_row0_col23, #T_fd084_row0_col24, #T_fd084_row0_col25, #T_fd084_row0_col26, #T_fd084_row0_col27, #T_fd084_row0_col28, #T_fd084_row0_col29, #T_fd084_row0_col30, #T_fd084_row1_col0, #T_fd084_row1_col1, #T_fd084_row1_col2, #T_fd084_row1_col3, #T_fd084_row1_col4, #T_fd084_row1_col5, #T_fd084_row1_col6, #T_fd084_row1_col7, #T_fd084_row1_col8, #T_fd084_row1_col9, #T_fd084_row1_col10, #T_fd084_row1_col11, #T_fd084_row1_col12, #T_fd084_row1_col13, #T_fd084_row1_col14, #T_fd084_row1_col15, #T_fd084_row1_col16, #T_fd084_row1_col17, #T_fd084_row1_col18, #T_fd084_row1_col19, #T_fd084_row1_col20, #T_fd084_row1_col21, #T_fd084_row1_col22, #T_fd084_row1_col23, #T_fd084_row1_col24, #T_fd084_row1_col25, #T_fd084_row1_col26, #T_fd084_row1_col27, #T_fd084_row1_col28, #T_fd084_row1_col29, #T_fd084_row1_col30, #T_fd084_row2_col0, #T_fd084_row2_col1, #T_fd084_row2_col2, #T_fd084_row2_col3, #T_fd084_row2_col4, #T_fd084_row2_col5, #T_fd084_row2_col6, #T_fd084_row2_col7, #T_fd084_row2_col8, #T_fd084_row2_col9, #T_fd084_row2_col10, #T_fd084_row2_col11, #T_fd084_row2_col12, #T_fd084_row2_col13, #T_fd084_row2_col14, #T_fd084_row2_col15, #T_fd084_row2_col16, #T_fd084_row2_col17, #T_fd084_row2_col18, #T_fd084_row2_col19, #T_fd084_row2_col20, #T_fd084_row2_col21, #T_fd084_row2_col22, #T_fd084_row2_col23, #T_fd084_row2_col24, #T_fd084_row2_col25, #T_fd084_row2_col26, #T_fd084_row2_col27, #T_fd084_row2_col28, #T_fd084_row2_col29, #T_fd084_row2_col30, #T_fd084_row3_col0, #T_fd084_row3_col1, #T_fd084_row3_col2, #T_fd084_row3_col3, #T_fd084_row3_col4, #T_fd084_row3_col5, #T_fd084_row3_col6, #T_fd084_row3_col7, #T_fd084_row3_col8, #T_fd084_row3_col9, #T_fd084_row3_col10, #T_fd084_row3_col11, #T_fd084_row3_col12, #T_fd084_row3_col13, #T_fd084_row3_col14, #T_fd084_row3_col15, #T_fd084_row3_col16, #T_fd084_row3_col17, #T_fd084_row3_col18, #T_fd084_row3_col19, #T_fd084_row3_col20, #T_fd084_row3_col21, #T_fd084_row3_col22, #T_fd084_row3_col23, #T_fd084_row3_col24, #T_fd084_row3_col25, #T_fd084_row3_col26, #T_fd084_row3_col27, #T_fd084_row3_col28, #T_fd084_row3_col29, #T_fd084_row3_col30, #T_fd084_row4_col0, #T_fd084_row4_col1, #T_fd084_row4_col2, #T_fd084_row4_col3, #T_fd084_row4_col4, #T_fd084_row4_col5, #T_fd084_row4_col6, #T_fd084_row4_col7, #T_fd084_row4_col8, #T_fd084_row4_col9, #T_fd084_row4_col10, #T_fd084_row4_col11, #T_fd084_row4_col12, #T_fd084_row4_col13, #T_fd084_row4_col14, #T_fd084_row4_col15, #T_fd084_row4_col16, #T_fd084_row4_col17, #T_fd084_row4_col18, #T_fd084_row4_col19, #T_fd084_row4_col20, #T_fd084_row4_col21, #T_fd084_row4_col22, #T_fd084_row4_col23, #T_fd084_row4_col24, #T_fd084_row4_col25, #T_fd084_row4_col26, #T_fd084_row4_col27, #T_fd084_row4_col28, #T_fd084_row4_col29, #T_fd084_row4_col30 {
#   background-color: #E9F6E2;
#   color: black;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_fd084">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd084_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_fd084_level0_col1" class="col_heading level0 col1" >Attrition</th>
#       <th id="T_fd084_level0_col2" class="col_heading level0 col2" >BusinessTravel</th>
#       <th id="T_fd084_level0_col3" class="col_heading level0 col3" >DailyRate</th>
#       <th id="T_fd084_level0_col4" class="col_heading level0 col4" >Department</th>
#       <th id="T_fd084_level0_col5" class="col_heading level0 col5" >DistanceFromHome</th>
#       <th id="T_fd084_level0_col6" class="col_heading level0 col6" >Education</th>
#       <th id="T_fd084_level0_col7" class="col_heading level0 col7" >EducationField</th>
#       <th id="T_fd084_level0_col8" class="col_heading level0 col8" >EnvironmentSatisfaction</th>
#       <th id="T_fd084_level0_col9" class="col_heading level0 col9" >Gender</th>
#       <th id="T_fd084_level0_col10" class="col_heading level0 col10" >HourlyRate</th>
#       <th id="T_fd084_level0_col11" class="col_heading level0 col11" >JobInvolvement</th>
#       <th id="T_fd084_level0_col12" class="col_heading level0 col12" >JobLevel</th>
#       <th id="T_fd084_level0_col13" class="col_heading level0 col13" >JobRole</th>
#       <th id="T_fd084_level0_col14" class="col_heading level0 col14" >JobSatisfaction</th>
#       <th id="T_fd084_level0_col15" class="col_heading level0 col15" >MaritalStatus</th>
#       <th id="T_fd084_level0_col16" class="col_heading level0 col16" >MonthlyIncome</th>
#       <th id="T_fd084_level0_col17" class="col_heading level0 col17" >MonthlyRate</th>
#       <th id="T_fd084_level0_col18" class="col_heading level0 col18" >NumCompaniesWorked</th>
#       <th id="T_fd084_level0_col19" class="col_heading level0 col19" >OverTime</th>
#       <th id="T_fd084_level0_col20" class="col_heading level0 col20" >PercentSalaryHike</th>
#       <th id="T_fd084_level0_col21" class="col_heading level0 col21" >PerformanceRating</th>
#       <th id="T_fd084_level0_col22" class="col_heading level0 col22" >RelationshipSatisfaction</th>
#       <th id="T_fd084_level0_col23" class="col_heading level0 col23" >StockOptionLevel</th>
#       <th id="T_fd084_level0_col24" class="col_heading level0 col24" >TotalWorkingYears</th>
#       <th id="T_fd084_level0_col25" class="col_heading level0 col25" >TrainingTimesLastYear</th>
#       <th id="T_fd084_level0_col26" class="col_heading level0 col26" >WorkLifeBalance</th>
#       <th id="T_fd084_level0_col27" class="col_heading level0 col27" >YearsAtCompany</th>
#       <th id="T_fd084_level0_col28" class="col_heading level0 col28" >YearsInCurrentRole</th>
#       <th id="T_fd084_level0_col29" class="col_heading level0 col29" >YearsSinceLastPromotion</th>
#       <th id="T_fd084_level0_col30" class="col_heading level0 col30" >YearsWithCurrManager</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd084_level0_row0" class="row_heading level0 row0" >1465</th>
#       <td id="T_fd084_row0_col0" class="data row0 col0" >36</td>
#       <td id="T_fd084_row0_col1" class="data row0 col1" >No</td>
#       <td id="T_fd084_row0_col2" class="data row0 col2" >Travel_Frequently</td>
#       <td id="T_fd084_row0_col3" class="data row0 col3" >884</td>
#       <td id="T_fd084_row0_col4" class="data row0 col4" >Research & Development</td>
#       <td id="T_fd084_row0_col5" class="data row0 col5" >23</td>
#       <td id="T_fd084_row0_col6" class="data row0 col6" >College</td>
#       <td id="T_fd084_row0_col7" class="data row0 col7" >Medical</td>
#       <td id="T_fd084_row0_col8" class="data row0 col8" >High</td>
#       <td id="T_fd084_row0_col9" class="data row0 col9" >Male</td>
#       <td id="T_fd084_row0_col10" class="data row0 col10" >41</td>
#       <td id="T_fd084_row0_col11" class="data row0 col11" >Very High</td>
#       <td id="T_fd084_row0_col12" class="data row0 col12" >Junior Level</td>
#       <td id="T_fd084_row0_col13" class="data row0 col13" >Laboratory Technician</td>
#       <td id="T_fd084_row0_col14" class="data row0 col14" >Very High</td>
#       <td id="T_fd084_row0_col15" class="data row0 col15" >Married</td>
#       <td id="T_fd084_row0_col16" class="data row0 col16" >2571</td>
#       <td id="T_fd084_row0_col17" class="data row0 col17" >12290</td>
#       <td id="T_fd084_row0_col18" class="data row0 col18" >4</td>
#       <td id="T_fd084_row0_col19" class="data row0 col19" >No</td>
#       <td id="T_fd084_row0_col20" class="data row0 col20" >17</td>
#       <td id="T_fd084_row0_col21" class="data row0 col21" >Excellent</td>
#       <td id="T_fd084_row0_col22" class="data row0 col22" >High</td>
#       <td id="T_fd084_row0_col23" class="data row0 col23" >1</td>
#       <td id="T_fd084

# %%
    # Print the shape of the DataFrame
print("The shape of data frame:", employee_data.shape)
# Print the length (number of rows) of the DataFrame
print("Number of Rows in the dataframe:", len(employee_data))
# Print the number of columns in the DataFrame
print("Number of Columns in the dataframe:", len(employee_data.columns))
# Out:
# The shape of data frame: (1470, 31)
# Number of Rows in the dataframe: 1470
# Number of Columns in the dataframe: 31

# %%
# Convert categorical variables into numerical form. 
label = LabelEncoder()
employee_data["Attrition"] = label.fit_transform(employee_data.Attrition)

# %%
 employee_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int32
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   object
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   object
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   object
#  12  JobLevel                  1470 non-null   object
#  13  JobRole                   1470 non-null   object
#  14  JobSatisfaction           1470 non-null   object
#  15  MaritalStatus             1470 non-null   object
#  16  MonthlyIncome             1470 non-null   int64
#  17  MonthlyRate               1470 non-null   int64
#  18  NumCompaniesWorked        1470 non-null   int64
#  19  OverTime                  1470 non-null   object
#  20  PercentSalaryHike         1470 non-null   int64
#  21  PerformanceRating         1470 non-null   object
#  22  RelationshipSatisfaction  1470 non-null   object
#  23  StockOptionLevel          1470 non-null   int64
#  24  TotalWorkingYears         1470 non-null   int64
#  25  TrainingTimesLastYear     1470 non-null   int64
#  26  WorkLifeBalance           1470 non-null   object
#  27  YearsAtCompany            1470 non-null   int64
#  28  YearsInCurrentRole        1470 non-null   int64
#  29  YearsSinceLastPromotion   1470 non-null   int64
#  30  YearsWithCurrManager      1470 non-null   int64
# dtypes: int32(1), int64(15), object(15)
# memory usage: 350.4+ KB

# %%
# Transform categorical data into dummies
dummy_col = [column for column in employee_data.drop('Attrition', axis=1).columns if employee_data[column].nunique() < 20]
data = pd.get_dummies(employee_data, columns=dummy_col, drop_first=True, dtype='uint8')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Columns: 136 entries, Age to YearsWithCurrManager_17
# dtypes: int32(1), int64(8), uint8(127)
# memory usage: 280.1 KB

# %%
print(data.shape)

# Remove duplicate Features
data = data.T.drop_duplicates()
data = data.T

# Remove Duplicate Rows
data.drop_duplicates(inplace=True)

print(data.shape)
# Out:
# (1470, 136)
# (1470, 136)

# %%
X = data.drop('Attrition', axis=1)
y = data.Attrition

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42,
                                                    stratify=y)

scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)
X_std = scaler.transform(X)

# %%
def feature_imp(df, model):
    fi = pd.DataFrame()
    fi["feature"] = df.columns
    fi["importance"] = model.feature_importances_
    return fi.sort_values(by="importance", ascending=False)

# %%
y_test.value_counts()[0] / y_test.shape[0]
# Out:
# 0.8390022675736961

# %%
stay = (y_train.value_counts()[0] / y_train.shape)[0]
leave = (y_train.value_counts()[1] / y_train.shape)[0]

print("===============TRAIN=================")
print(f"Staying Rate: {stay * 100:.2f}%")
print(f"Leaving Rate: {leave * 100 :.2f}%")

stay = (y_test.value_counts()[0] / y_test.shape)[0]
leave = (y_test.value_counts()[1] / y_test.shape)[0]

print("===============TEST=================")
print(f"Staying Rate: {stay * 100:.2f}%")
print(f"Leaving Rate: {leave * 100 :.2f}%")
# Out:
# ===============TRAIN=================
# Staying Rate: 83.87%
# Leaving Rate: 16.13%
# ===============TEST=================
# Staying Rate: 83.90%
# Leaving Rate: 16.10%
